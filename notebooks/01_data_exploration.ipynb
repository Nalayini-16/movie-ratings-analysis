# %%
import pandas as pd

df = pd.read_csv('../data/imdb_top_1000.csv')
df.head()
# Out:
#    rank  year duration age_limit  rating numberof_ratings  Metascore  \
# 0     1  1994   2h 22m        15     9.3           (2.9M)       82.0
# 1     2  1972   2h 55m        15     9.2             (2M)      100.0
# 2     3  2008   2h 32m       12A     9.0           (2.9M)       84.0
# 3     4  2003   3h 21m       12A     9.0             (2M)       94.0
# 4     5  1993   3h 15m        15     9.0           (1.5M)       95.0
#
#                                          description  \
# 0  Over the course of several years, two convicts...
# 1  The aging patriarch of an organized crime dyna...
# 2  When the menace known as the Joker wreaks havo...
# 3  Gandalf and Aragorn lead the World of Men agai...
# 4  In German-occupied Poland during World War II,...
#
#                                              name
# 0                        The Shawshank Redemption
# 1                                   The Godfather
# 2                                 The Dark Knight
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   rank              1000 non-null   int64
#  1   year              1000 non-null   int64
#  2   duration          1000 non-null   str
#  3   age_limit         997 non-null    str
#  4   rating            1000 non-null   float64
#  5   numberof_ratings  1000 non-null   str
#  6   Metascore         842 non-null    float64
#  7   description       1000 non-null   str
#  8   name              1000 non-null   str
# dtypes: float64(2), int64(2), str(5)
# memory usage: 70.4 KB

# %%
df.isnull().sum()
# Out:
# rank                  0
# year                  0
# duration              0
# age_limit             3
# rating                0
# numberof_ratings      0
# Metascore           158
# description           0
# name                  0
# dtype: int64

# %%
df['duration'].head(10)
df['numberof_ratings'].head(10)
# Out:
# 0    (2.9M)
# 1      (2M)
# 2    (2.9M)
# 3      (2M)
# 4    (1.5M)
# 5    (871K)
# 6    (1.4M)
# 7      (2M)
# 8    (2.2M)
# 9    (119K)
# Name: numberof_ratings, dtype: str

# %%
def convert_votes(value):
    value = value.strip('()')
    if 'M' in value:
        return float(value.replace('M', ''))
    elif 'K' in value:
        return float(value.replace('K', ''))
    else:
        return float(value)
df['numberof_ratings'] = df['numberof_ratings'].apply(convert_votes)

# %%
df['numberof_ratings'].head(10)
df['numberof_ratings'].dtype
# Out:
# dtype('float64')
